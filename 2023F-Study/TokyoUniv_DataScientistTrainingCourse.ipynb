# %%
#ノートブックでやってみる方

# %%
import random
import numpy as np
import matplotlib
matplotlib.use('TkAgg') #グラフ表示するときこれがないと出てこないぽい。
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# 散布図
random.seed(0)
x = np.random.rand(30)
y = np.sin(x) + np.random.rand(30)

plt.figure(figsize=(20,6))
plt.plot(x, y, 'o')
plt.title('Title Name')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)

# %%
pwd
# Out:
# '/Users/koguretaichi/PycharmProjects/pythonProject/2023F-Study'
